# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 150px; float: left;"> <img src="data/D4Sci_logo_ball.png" alt="Data For Science, Inc" align="left" border="0"> </div>
#     <div style="float: left; margin-left: 10px;"> <h1>NLP with PyTorch</h1>
# <h1>Text Classification</h1>
#         <p>Bruno Gonçalves<br/>
#         <a href="http://www.data4sci.com/">www.data4sci.com</a><br/>
#             @bgoncalves, @data4sci</p></div>
# </div>

# %%
import warnings
warnings.filterwarnings('ignore')

import gzip
from collections import Counter
from pprint import pprint

import pandas as pd
import numpy as np
np.random.seed(42)

import matplotlib
import matplotlib.pyplot as plt 

from tqdm import tqdm

import keras
import tensorflow as tf
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.layers import Embedding
from keras_preprocessing import sequence

import watermark

# %load_ext watermark
# %matplotlib inline

# %% [markdown]
# We start by print out the versions of the libraries we're using for future reference

# %%
# %watermark -n -v -m -g -iv
# Out:
# Python implementation: CPython
# Python version       : 3.11.7
# IPython version      : 8.12.3
#
# Compiler    : Clang 14.0.6
# OS          : Darwin
# Release     : 24.2.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 16
# Architecture: 64bit
#
# Git hash: cbc605876514759eff1e35662aa7a98f5b6e3539
#
# matplotlib         : 3.8.0
# tensorflow         : 2.18.0
# pandas             : 2.2.3
# json               : 2.0.9
# keras_preprocessing: 1.1.2
# watermark          : 2.4.3
# keras              : 3.8.0
# numpy              : 1.26.4

# %% [markdown]
# Load default figure style

# %%
plt.style.use('d4sci.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# # IMDB Dataset

# %%
top_words = 10_000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=top_words)

# %% [markdown]
# Each word is associated with a unique ID. We can easily obtain the dictionary mapping words to IDs

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
word_dict = imdb.get_word_index()

# %% [markdown]
# So we can check what the id of each word is

# %%
word_dict['casting']
# Out:
# 970

# %%
word_dict['director']
# Out:
# 164

# %% [markdown]
# We also invert the index so that we can recover the original text. A few special tokens are reserved at the beginning of the id range

# %%
word_list = ["<PAD>", "<START>", "<UNK>", "<UNUSED>"]
word_list.extend([k for k, v in sorted(word_dict.items(), key = lambda x: x[1])])
word_list = np.array(word_list)

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
" ".join(word_list[X_train[0]])
# Out:
# "<START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %% [markdown]
# Each review has associated with it a value of 0 or 1.

# %%
set(y_train)
# Out:
# {0, 1}

# %% [markdown]
# So the corresponding rating for review is

# %%
y_train[0]
# Out:
# 1

# %% [markdown]
# 1 means positive, while 0 means negative

# %%
" ".join(word_list[X_train[4]])
# Out:
# "<START> worst mistake of my life br br i picked this movie up at target for 5 because i figured hey it's sandler i can get some cheap laughs i was wrong completely wrong mid way through the film all three of my friends were asleep and i was still suffering worst plot worst script worst movie i have ever seen i wanted to hit my head up against a wall for an hour then i'd stop and you know why because it felt damn good upon bashing my head in i stuck that damn movie in the <UNK> and watched it burn and that felt better than anything else i've ever done it took american psycho army of darkness and kill bill just to get over that crap i hate you sandler for actually going through with this and ruining a whole day of my life"

# %%
y_train[4]
# Out:
# 0

# %% [markdown]
# Our dataset is split into two equal parts, the training and the testing dataset

# %%
print('Shape of training data:', X_train.shape)
print('Shape of test data:', X_test.shape)
# Out:
# Shape of training data: (25000,)
# Shape of test data: (25000,)

# %% [markdown]
# # Feed Forward Model

# %% [markdown]
# We'll start by training a simple FF model without any fancyness. The first step is to padd each instance so that they all have the same size. Here we'll use the first 450 words. If the review is longer, we trucate it, while if its shorter we pad it

# %%
max_words = 500
X_train = sequence.pad_sequences(X_train, maxlen=max_words)
X_test = sequence.pad_sequences(X_test, maxlen=max_words)

# %%
" ".join(word_list[X_train[0]])
# Out:
# "<PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %% [markdown]
# ## Model Structure

# %% [markdown]
# Our model will have an embedding layer to turn our numerical ids into vectors, a hidden dense layer of 32 neurons and ReLu activation followed by an output layer with just one neuron and a sigmoid activation

# %%
model = Sequential() # []
model.add(Embedding(top_words, 50, input_shape=(max_words,))) # [].append()
## <==> ##
model.add(Flatten()) # [].append()
model.add(Dense(32, activation='relu')) # [].append()
model.add(Dense(1, activation='sigmoid')) # [].append()

# %% [markdown]
# In summary:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 500, 50)        │       500,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │       800,032 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,300,065 (4.96 MB)
#  Trainable params: 1,300,065 (4.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Next we compile our model using a binary cross entropy loss function and the Adam optimizer

# %%
model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %% [markdown]
# The final step is to fit the model using the training data. We also supply the test data for validation purposes

# %%
history = model.fit(X_train, y_train, # Training data
          validation_data=(X_test, y_test), # The testing data for validation
          epochs=10, # How many epochs to train for
          batch_size=128, # The batch size. Gradients are updated after each batch 
          verbose=1) # The level of detail in the output
# Out:
# Epoch 1/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6060 - loss: 0.6118 - val_accuracy: 0.8490 - val_loss: 0.3434
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9308 - loss: 0.1857 - val_accuracy: 0.8663 - val_loss: 0.3223
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9880 - loss: 0.0530 - val_accuracy: 0.8620 - val_loss: 0.3769
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9987 - loss: 0.0115 - val_accuracy: 0.8623 - val_loss: 0.4239
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8643 - val_loss: 0.4537
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8655 - val_loss: 0.4805
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 7.6749e-04 - val_accuracy: 0.8662 - val_loss: 0.5059
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 4.3842e-04 - val_accuracy: 0.8665 - val_loss: 0.5308
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.6240e-04 - val_accuracy: 0.8664 - val_loss: 0.5546
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 1.7496e-04 - val_accuracy: 0.8673 - val_loss: 0.5722

# %% [markdown]
# Small utility function to display the results

# %%
def plot_history(history):    
    fig, ax_lst = plt.subplots(1, 2, sharex=True, sharey=True)

    epochs = np.array(history.epoch) + 1
    
    ax_lst[0].plot(epochs, history.history['loss'], label='Training')
    ax_lst[0].plot(epochs, history.history['val_loss'], label='Testing')
    ax_lst[0].set_ylabel('Loss')
    ax_lst[0].set_xlabel('Epoch')
    ax_lst[0].set_xticks(epochs)
    
    best_epoch = np.argmin(history.history['val_loss']) + 1
    ax_lst[0].axvline(x=best_epoch, linestyle=':', color=colors[2])
    ax_lst[0].legend()
    

    ax_lst[1].plot(epochs, history.history['accuracy'], label='Training')
    ax_lst[1].plot(epochs, history.history['val_accuracy'], label='Testing')
    ax_lst[1].set_ylabel('Accuracy')
    ax_lst[1].set_xlabel('Epoch')
    ax_lst[1].set_xticks(epochs)
    ax_lst[1].axvline(x=best_epoch, linestyle=':', color=colors[2])

    fig.tight_layout()

# %%
plot_history(history)

# %% [markdown]
# Looks like we are overfitting the data after just a few epochs

# %% [markdown]
# # Convolutional Model

# %% [markdown]
# Now we add a convolution layer between the embedding layer and the dense layer

# %%
model = Sequential()
model.add(Embedding(top_words, 50, input_length=max_words))
## <==> ##
model.add(Conv1D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling1D())
## <==> ##
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# Compile and fit the model

# %%
model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, 
          validation_data=(X_test, y_test), # The testing data for validation
          epochs=10, # How many epochs to train for
          batch_size=128, # The batch size. Gradients are updated after each batch 
          verbose=1) # The level of detail in the output
# Out:
# Epoch 1/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5608 - loss: 0.6518 - val_accuracy: 0.8730 - val_loss: 0.3057
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9057 - loss: 0.2434 - val_accuracy: 0.8772 - val_loss: 0.2928
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9448 - loss: 0.1570 - val_accuracy: 0.8818 - val_loss: 0.3017
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9661 - loss: 0.1068 - val_accuracy: 0.8814 - val_loss: 0.3269
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9809 - loss: 0.0717 - val_accuracy: 0.8763 - val_loss: 0.3925
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9902 - loss: 0.0418 - val_accuracy: 0.8706 - val_loss: 0.4811
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9949 - loss: 0.0251 - val_accuracy: 0.8574 - val_loss: 0.5194
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9970 - loss: 0.0185 - val_accuracy: 0.8636 - val_loss: 0.5754
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9985 - loss: 0.0113 - val_accuracy: 0.8667 - val_loss: 0.6439
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9993 - loss: 0.0059 - val_accuracy: 0.8643 - val_loss: 0.6985

# %% [markdown]
# This model takes significantly longer to train, but produces much better results

# %%
plot_history(history)

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#      <img src="data/D4Sci_logo_full.png" alt="Data For Science, Inc" align="center" border="0" width=300px>
# </div>
