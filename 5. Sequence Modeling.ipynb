# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 150px; float: left;"> <img src="data/D4Sci_logo_ball.png" alt="Data For Science, Inc" align="left" border="0"> </div>
#     <div style="float: left; margin-left: 10px;"> <h1>Natural Language Processing</h1>
# <h1>Sequence Modeling</h1>
#         <p>Bruno Gonçalves<br/>
#         <a href="http://www.data4sci.com/">www.data4sci.com</a><br/>
#             @bgoncalves, @data4sci</p></div>
# </div>

# %%
import warnings
warnings.filterwarnings('ignore')

import gzip
from collections import Counter
from pprint import pprint
import time

import random

import pandas as pd
import numpy as np
np.random.seed(42)

import matplotlib
import matplotlib.pyplot as plt 

from tqdm.notebook import tqdm
tqdm.pandas()

RANDOM_SEED = 123
np.random.seed(RANDOM_SEED)

import torch
torch.manual_seed(RANDOM_SEED)

import torch.nn as nn
import torch.nn.functional as F

import torchtext
from torchtext.data import Field, BucketIterator, TabularDataset

from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader

import torchview
from torchview import draw_graph

import watermark

# %load_ext watermark
# %matplotlib inline

# %% [markdown]
# We start by print out the versions of the libraries we're using for future reference

# %%
# %watermark -n -v -m -g -iv
# Out:
# Python implementation: CPython
# Python version       : 3.11.7
# IPython version      : 8.12.3
#
# Compiler    : Clang 14.0.6
# OS          : Darwin
# Release     : 24.3.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 16
# Architecture: 64bit
#
# Git hash: ff70dc0d4a154aacbb783ca5f9a29cf428d000f6
#
# torchview : 0.2.6
# torchtext : 0.6.0
# pandas    : 2.2.3
# numpy     : 1.26.4
# matplotlib: 3.8.0
# torch     : 2.6.0
# watermark : 2.4.3

# %% [markdown]
# Load default figure style

# %%
plt.style.use('./d4sci.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# # Load the Dataset

# %% [markdown]
# Define the text and label fields

# %%
TEXT = Field(tokenize='spacy', tokenizer_language='en_core_web_sm')
LABEL = torchtext.data.LabelField(dtype=torch.long)

# %% [markdown]
# Load the dataset with the proper schema

# %%
fields = [('TEXT_COLUMN_NAME', TEXT), ('LABEL_COLUMN_NAME', LABEL)]

dataset = TabularDataset(path='data/IMDB Dataset.csv', format='csv', skip_header=True, fields=fields)

# %% [markdown]
# Split the dataset into training, validation, and test partitions:

# %%
X_train, X_test = dataset.split(split_ratio=[0.8, 0.2],random_state=random.seed(RANDOM_SEED))
X_train, X_validation = X_train.split(split_ratio=[0.85, 0.15],random_state=random.seed(RANDOM_SEED))

# %%
print('Shape of training data:', len(X_train))
print('Shape of test data:', len(X_test))
print('Shape of validation data:', len(X_validation))
# Out:
# Shape of training data: 34000
# Shape of test data: 10000
# Shape of validation data: 6000

# %% [markdown]
# ## Build Vocabulary

# %% [markdown]
# Build the vocabulary based on the top "vocabulary_size" words:

# %%
vocabulary_size = 20_000

# %%
TEXT.build_vocab(X_train, max_size=vocabulary_size)
LABEL.build_vocab(X_train)

print(f'Vocabulary size: {len(TEXT.vocab)}')
print(f'Number of classes: {len(LABEL.vocab)}')
# Out:
# Vocabulary size: 20002
# Number of classes: 2

# %% [markdown]
# ## Define Data Loaders

# %%
batch_size = 128
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')

# %%
train_loader, valid_loader, test_loader = BucketIterator.splits((X_train, X_validation, X_test),
         batch_size=batch_size,
         sort_within_batch=False,
         sort_key=lambda x: len(x.TEXT_COLUMN_NAME),
         device=device
    )

# %% [markdown]
# Finally, we are ready to define our models

# %% [markdown]
# # Simple RNN model
#
# As the structure of the model is the same for RNN, GRU, and LSTMs, we implement just one of them for demonstration purposes. We can easily plugin another type of layer as needed

# %%
class RNN(nn.Module):
    def __init__(self, input_dim, embedding_size, hidden_size, output_size):
        super().__init__()

        self.embedding = nn.Embedding(input_dim, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size)        
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, text):        
        embedded = self.embedding(text)
        output, (hidden, cell) = self.rnn(embedded)
        hidden.squeeze_(0)        
        output = self.fc(hidden)
        
        return output

# %%
embedding_size = 128
hidden_size = 256
num_classes = 2

# %%
model = RNN(len(TEXT.vocab), # vocabulary_size + 2 for <pad> and <unk>
            embedding_size,
            hidden_size,
            num_classes 
           )

# %%
print(model)
# Out:
# RNN(
#   (embedding): Embedding(20002, 128)
#   (rnn): LSTM(128, 256)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
learning_rate = 0.005
n_epochs = 15

# %%
model = model.to(device)
optimizer = Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training

# %%
def compute_accuracy(model, data_loader, device):

    with torch.no_grad():

        correct_pred, num_examples = 0, 0

        for i, (features, targets) in enumerate(data_loader):

            features = features.to(device)
            targets = targets.float().to(device)

            logits = model(features)
            loss = F.cross_entropy(logits, targets)
            _, predicted_labels = torch.max(logits, 1)

            num_examples += targets.size(0)
            correct_pred += (predicted_labels == targets).sum()
            
    return correct_pred.float()/num_examples * 100, loss

# %% [markdown]
# Based on this [notebook](https://github.com/rasbt/stat453-deep-learning-ss21/tree/main/L15)

# %%
start_time = time.time()

history = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': [],
        'epochs': n_epochs
    }

for epoch in range(n_epochs):
    model.train()
    for batch_idx, batch_data in tqdm(enumerate(train_loader), 
                                      total=len(train_loader), 
                                      desc='Epoch: %u' % (epoch+1),
                                      leave=True):
        
        text = batch_data.TEXT_COLUMN_NAME.to(device)
        labels = batch_data.LABEL_COLUMN_NAME.to(device)

        # Forward pass
        logits = model(text)
        
        # Back propagation
        loss = F.cross_entropy(logits, labels)
        optimizer.zero_grad()
        loss.backward()
        
        # update weights
        optimizer.step()
        
        if not batch_idx % 50:
            print (f'Epoch: {epoch+1:03d}/{n_epochs:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} | '
                   f'Loss: {loss:.4f}')

    with torch.set_grad_enabled(False):
        print(f'training accuracy: '
              f'{compute_accuracy(model, train_loader, device)[0]:.2f}%'
              f'\nvalid accuracy: '
              f'{compute_accuracy(model, valid_loader, device)[0]:.2f}%')
    
    history['train_loss'].append(loss.to('cpu').detach().numpy())
    history['train_acc'].append(compute_accuracy(model, train_loader, device)[0].to('cpu').detach().numpy())
    
    val_acc, val_loss = compute_accuracy(model, valid_loader, device)
    
    history['val_acc'].append(val_acc.to('cpu').detach().numpy())
    history['val_loss'].append(val_loss.to('cpu').detach().numpy())

    print(f'Time elapsed: {(time.time() - start_time)/60:.2f} min')
    
print(f'Total Training Time: {(time.time() - start_time)/60:.2f} min')
print(f'Test accuracy: {compute_accuracy(model, test_loader, device)[0]:.2f}%')
# Out:
# Epoch: 1:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 001/015 | Batch 000/266 | Loss: 0.7136
# Epoch: 001/015 | Batch 050/266 | Loss: 0.6994
# Epoch: 001/015 | Batch 100/266 | Loss: 0.6898
# Epoch: 001/015 | Batch 150/266 | Loss: 0.6926
# Epoch: 001/015 | Batch 200/266 | Loss: 0.6961
# Epoch: 001/015 | Batch 250/266 | Loss: 0.6951
# training accuracy: 49.94%
# valid accuracy: 49.82%
# Time elapsed: 0.83 min
# Epoch: 2:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 002/015 | Batch 000/266 | Loss: 0.6954
# Epoch: 002/015 | Batch 050/266 | Loss: 0.6933
# Epoch: 002/015 | Batch 100/266 | Loss: 0.6932
# Epoch: 002/015 | Batch 150/266 | Loss: 0.6926
# Epoch: 002/015 | Batch 200/266 | Loss: 0.6930
# Epoch: 002/015 | Batch 250/266 | Loss: 0.6915
# training accuracy: 50.14%
# valid accuracy: 49.48%
# Time elapsed: 1.60 min
# Epoch: 3:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 003/015 | Batch 000/266 | Loss: 0.6938
# Epoch: 003/015 | Batch 050/266 | Loss: 0.6948
# Epoch: 003/015 | Batch 100/266 | Loss: 0.6909
# Epoch: 003/015 | Batch 150/266 | Loss: 0.6957
# Epoch: 003/015 | Batch 200/266 | Loss: 0.6912
# Epoch: 003/015 | Batch 250/266 | Loss: 0.6895
# training accuracy: 50.25%
# valid accuracy: 50.00%
# Time elapsed: 2.37 min
# Epoch: 4:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 004/015 | Batch 000/266 | Loss: 0.6914
# Epoch: 004/015 | Batch 050/266 | Loss: 0.6922
# Epoch: 004/015 | Batch 100/266 | Loss: 0.7227
# Epoch: 004/015 | Batch 150/266 | Loss: 0.6852
# Epoch: 004/015 | Batch 200/266 | Loss: 0.6500
# Epoch: 004/015 | Batch 250/266 | Loss: 0.4800
# training accuracy: 81.58%
# valid accuracy: 78.50%
# Time elapsed: 3.17 min
# Epoch: 5:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 005/015 | Batch 000/266 | Loss: 0.4634
# Epoch: 005/015 | Batch 050/266 | Loss: 0.4377
# Epoch: 005/015 | Batch 100/266 | Loss: 0.4518
# Epoch: 005/015 | Batch 150/266 | Loss: 0.3126
# Epoch: 005/015 | Batch 200/266 | Loss: 0.3015
# Epoch: 005/015 | Batch 250/266 | Loss: 0.4028
# training accuracy: 88.18%
# valid accuracy: 83.22%
# Time elapsed: 4.05 min
# Epoch: 6:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 006/015 | Batch 000/266 | Loss: 0.3279
# Epoch: 006/015 | Batch 050/266 | Loss: 0.2397
# Epoch: 006/015 | Batch 100/266 | Loss: 0.2794
# Epoch: 006/015 | Batch 150/266 | Loss: 0.1937
# Epoch: 006/015 | Batch 200/266 | Loss: 0.3591
# Epoch: 006/015 | Batch 250/266 | Loss: 0.2606
# training accuracy: 91.13%
# valid accuracy: 84.63%
# Time elapsed: 4.89 min
# Epoch: 7:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 007/015 | Batch 000/266 | Loss: 0.2139
# Epoch: 007/015 | Batch 050/266 | Loss: 0.1716
# Epoch: 007/015 | Batch 100/266 | Loss: 0.2427
# Epoch: 007/015 | Batch 150/266 | Loss: 0.2396
# Epoch: 007/015 | Batch 200/266 | Loss: 0.1895
# Epoch: 007/015 | Batch 250/266 | Loss: 0.1987
# training accuracy: 94.79%
# valid accuracy: 86.77%
# Time elapsed: 5.71 min
# Epoch: 8:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 008/015 | Batch 000/266 | Loss: 0.1151
# Epoch: 008/015 | Batch 050/266 | Loss: 0.1529
# Epoch: 008/015 | Batch 100/266 | Loss: 0.2552
# Epoch: 008/015 | Batch 150/266 | Loss: 0.1242
# Epoch: 008/015 | Batch 200/266 | Loss: 0.1305
# Epoch: 008/015 | Batch 250/266 | Loss: 0.1312
# training accuracy: 96.30%
# valid accuracy: 87.40%
# Time elapsed: 6.51 min
# Epoch: 9:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 009/015 | Batch 000/266 | Loss: 0.0921
# Epoch: 009/015 | Batch 050/266 | Loss: 0.1425
# Epoch: 009/015 | Batch 100/266 | Loss: 0.1446
# Epoch: 009/015 | Batch 150/266 | Loss: 0.1433
# Epoch: 009/015 | Batch 200/266 | Loss: 0.1018
# Epoch: 009/015 | Batch 250/266 | Loss: 0.0978
# training accuracy: 96.99%
# valid accuracy: 87.50%
# Time elapsed: 7.31 min
# Epoch: 10:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 010/015 | Batch 000/266 | Loss: 0.0517
# Epoch: 010/015 | Batch 050/266 | Loss: 0.0906
# Epoch: 010/015 | Batch 100/266 | Loss: 0.1588
# Epoch: 010/015 | Batch 150/266 | Loss: 0.0761
# Epoch: 010/015 | Batch 200/266 | Loss: 0.0658
# Epoch: 010/015 | Batch 250/266 | Loss: 0.1385
# training accuracy: 98.19%
# valid accuracy: 87.67%
# Time elapsed: 8.08 min
# Epoch: 11:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 011/015 | Batch 000/266 | Loss: 0.0202
# Epoch: 011/015 | Batch 050/266 | Loss: 0.0658
# Epoch: 011/015 | Batch 100/266 | Loss: 0.0204
# Epoch: 011/015 | Batch 150/266 | Loss: 0.0362
# Epoch: 011/015 | Batch 200/266 | Loss: 0.1077
# Epoch: 011/015 | Batch 250/266 | Loss: 0.0704
# training accuracy: 98.58%
# valid accuracy: 87.35%
# Time elapsed: 8.84 min
# Epoch: 12:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 012/015 | Batch 000/266 | Loss: 0.1099
# Epoch: 012/015 | Batch 050/266 | Loss: 0.0353
# Epoch: 012/015 | Batch 100/266 | Loss: 0.0539
# Epoch: 012/015 | Batch 150/266 | Loss: 0.0410
# Epoch: 012/015 | Batch 200/266 | Loss: 0.1078
# Epoch: 012/015 | Batch 250/266 | Loss: 0.0278
# training accuracy: 98.80%
# valid accuracy: 87.78%
# Time elapsed: 9.60 min
# Epoch: 13:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 013/015 | Batch 000/266 | Loss: 0.0743
# Epoch: 013/015 | Batch 050/266 | Loss: 0.0198
# Epoch: 013/015 | Batch 100/266 | Loss: 0.0663
# Epoch: 013/015 | Batch 150/266 | Loss: 0.0268
# Epoch: 013/015 | Batch 200/266 | Loss: 0.1035
# Epoch: 013/015 | Batch 250/266 | Loss: 0.0613
# training accuracy: 99.06%
# valid accuracy: 87.52%
# Time elapsed: 25.31 min
# Epoch: 14:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 014/015 | Batch 000/266 | Loss: 0.0163
# Epoch: 014/015 | Batch 050/266 | Loss: 0.1022
# Epoch: 014/015 | Batch 100/266 | Loss: 0.0550
# Epoch: 014/015 | Batch 150/266 | Loss: 0.0487
# Epoch: 014/015 | Batch 200/266 | Loss: 0.0247
# Epoch: 014/015 | Batch 250/266 | Loss: 0.0214
# training accuracy: 98.45%
# valid accuracy: 87.40%
# Time elapsed: 28.66 min
# Epoch: 15:   0%|          | 0/266 [00:00<?, ?it/s]
# Epoch: 015/015 | Batch 000/266 | Loss: 0.0452
# Epoch: 015/015 | Batch 050/266 | Loss: 0.0762
# Epoch: 015/015 | Batch 100/266 | Loss: 0.0183
# Epoch: 015/015 | Batch 150/266 | Loss: 0.0227
# Epoch: 015/015 | Batch 200/266 | Loss: 0.0505
# Epoch: 015/015 | Batch 250/266 | Loss: 0.0796
# training accuracy: 99.06%
# valid accuracy: 87.23%
# Time elapsed: 44.40 min
# Total Training Time: 44.40 min
# Test accuracy: 87.59%

# %%
def plot_history(history):    
    fig, ax_lst = plt.subplots(1, 2, sharex=True, sharey=False)
    
    epochs = range(history['epochs'])
    
    ax_lst[0].plot(epochs, history['train_loss'], label='Training')
    ax_lst[0].plot(epochs, history['val_loss'], label='Testing')
    ax_lst[0].set_ylabel('Loss')
    ax_lst[0].set_xlabel('Epoch')
    ax_lst[0].set_xticks(epochs)
    
    ax_lst[1].plot(epochs, history['train_acc'], label='Training')
    ax_lst[1].plot(epochs, history['val_acc'], label='Testing')
    ax_lst[1].set_ylabel('Accuracy')
    ax_lst[1].set_xlabel('Epoch')
    ax_lst[1].set_xticks(epochs)

    ax_lst[1].legend()
    
    fig.tight_layout()

# %%
plot_history(history)

# %% [markdown]
# <center>
#      <img src="data/D4Sci_logo_full.png" alt="Data For Science, Inc" align="center" border="0" width=300px>
# </center>
